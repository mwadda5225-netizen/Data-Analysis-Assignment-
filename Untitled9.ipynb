# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
plt.style.use('bmh')

# %%
pd.set_option('display.max_columns',50)

# %%
hotels=pd.read_csv("https://osf.io/y6jvb/download")

# %%
hotels
# Out:
#      country city_actual  rating_count center1label center2label  \
# 0    Austria      Vienna          36.0  City centre    Donauturm
# 1    Austria      Vienna         189.0  City centre    Donauturm
# 2    Austria      Vienna          53.0  City centre    Donauturm
# 3    Austria      Vienna          55.0  City centre    Donauturm
# 4    Austria      Vienna          33.0  City centre    Donauturm
# ..       ...         ...           ...          ...          ...
# 423  Austria      Vienna           2.0  City centre    Donauturm
# 424  Austria      Vienna         145.0  City centre    Donauturm
# 425  Austria      Vienna         112.0  City centre    Donauturm
# 426  Austria      Vienna         169.0  City centre    Donauturm
# 427  Austria      Vienna          80.0  City centre    Donauturm
#
#     neighbourhood  price    city  stars  ratingta  ratingta_count  \
# 0     17. Hernals     81  Vienna    4.0       4.5           216.0
# ...

# %%
hotels.describe()

# %%
hotels=hotels[hotels["accommodation_type"]=="Hotel"]

# %%
hotels

# %%
table.rename_covariates({"Intercept":"Constant"})
table.custom_colums(["Homoskedastic SE", "Hetroskedastic roburst SE"]), [1,1]

# %%
html=table

# %%
hotels[predprice] = simple_reg.fittedvalues
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2516511807.py in <cell line: 0>()
# ----> 1 hotels[predprice] = simple_reg.fittedvalues
#
# NameError: name 'simple_reg' is not defined

# %%
hotels.sort_values(by="e").head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1194413652.py in <cell line: 0>()
# ----> 1 hotels.sort_values(by="e").head(5)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'e'

# %%
hotels.sort_values(by="e", ascending=False).head(5).filter(["hotel_id",])

# %%
hotels["inprice"]=np.log(hotels["price"])

# %%
hotels.describe()

# %%
hotels["describe2"]=np.where(hotels["distance"]<0.05,0.05,hotels["distance"])

# %%
hotels["Indistance"] = np.log(hotels["describe2"])

# %%
reg1 =smf.ols("price"~"distance",data=hotels).fit()

# %%
print(reg1.summary())

# %%
reg2 =smf.ols("price"~"Indistance",data=hotels).fit(cov_type)

# %%
table = Stargazer ([reg1, reg2, reg3, reg4])
table. rename_covariates({"Intercept": "Constant"})
table. custom_columns (["Level-Level", "Level-Log", "Log-Level", "Log-Log"], [1,u
41, 1, 11)
table

# %%
hotels["distance_sq"]= hotels["distance"] **2

# %%
reg5=smf.ols("price~distance+distance_sq", data=hotels).fit(cov_type="HC3")
print(reg5. summary())

# %%
from os import rename
table2=Stargazer([reg1,reg2,reg3,reg4,reg5])
table2.rename_covariates({"Intercept":"Constant":"distance":"Distance","distance_sq":"Squared Distance","indistance":"Indistance":"In(Distance)"})
table2.custom_columns (["Level-Level", "Level-Log", "Log-Level", "Log-Log"]

# %%
sns.regplot(data=hotels, x="distance", y="price")
